# %%
import pandas as pd 
import numpy as np

df = pd.read_csv('olimpics_dataset/athlete_events.csv')

# %%
df.loc[[0,30], 'Weight'] = np.nan
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0     NaN           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
# información relevante del df
#df.info()

# ver cantidad de valores nulos
df.isna().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62877
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
#Options
# LLenar con valores arbitrarios
df.fillna(df['Weight'].mean()).head()

# Interpolte, si encuentra un patrón lo va a repetir
# df.fillna(df['Weight'].interpolate())
# Out:
#    ID                      Name Sex   Age     Height    Weight  \
# 0   1                 A Dijiang   M  24.0  180.00000  70.70232
# 1   2                  A Lamusi   M  23.0  170.00000  60.00000
# 2   3       Gunnar Nielsen Aaby   M  24.0   70.70232  70.70232
# 3   4      Edgar Lindenau Aabye   M  34.0   70.70232  70.70232
# 4   5  Christine Jacoba Aaftink   F  21.0  185.00000  82.00000
#
#              Team  NOC        Games  Year  Season       City          Sport  \
# 0           China  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1           China  CHN  2012 Summer  2012  Summer     London           Judo
# 2         Denmark  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  Denmark/Sweden  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4     Netherlands  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event     Medal
# 0       Basketball Men's Basketball  70.70232
# ...

# %%
# Eliminar filas con na
#df.dropna().head()

#Eliminar filas con na en una caracteristica en especifico
df.dropna(subset='Name', inplace=True)

# %%
# Mostrar filas con na
df = df[df['Weight'].isna()]
df
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0     NaN
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 26           8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 27           8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# ...        ...                                 ...  ..   ...     ...     ...
# 271038  135539               Marius Edmund Zwiller   M  18.0     NaN     NaN
# 271042  135542                      Werner Zwingli   M  29.0     NaN     NaN
# 271043  135542                      Werner Zwingli   M  29.0     NaN     NaN
# 271075  135552     Jan (Johann-) Zybert (Siebert-)   M  20.0     NaN     NaN
# 271100  135561                       Frantiek Zyka   M  26.0     NaN     NaN
#
# ...
